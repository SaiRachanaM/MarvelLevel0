# %% [markdown]
# # Task 20:Notebook Ninja – Getting Started with Jupyter
#
# ## Introduction
# Welcome to my first Jupyter Notebook!
# In this notebook, I will practice combining **Markdown**, *Python code*, and visualizations.
#
# ## Goals:
# - Markdown & Presentation Skills on Jupyter Notebook
# - Python Coding & Visualization on Jupyter Notebook
# - Develop the habit of documenting your thought process clearly.
#
# ## Formating Text
# - **Bold**
# - *Italics*
# - Horizontal Line
#  ---
#
#
#
#
# ## Embedded Image
# ![Mc D logo](attachment:fc98d4bb-2fee-41ac-8a48-e56a27abed69.png)
#
# ## Code Snippet
# ```python
# # Example Python snippet
# a = 10
# b = 20
# print(a + b)

# %%
x = 12
y = 3
sum = x + y
print(sum)
# Out:
# 15

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]

y = x 

plt.plot(x, y)
plt.title("Line Graph of y = x")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Summary
# In this notebook, I practiced:
# - Using Markdown for titles, formatting, lists, and embedding images
# - Writing clean Python code with variables and calculations
# - Creating a simple visualization with Matplotlib
#
# This helped me build confidence in combining **code**, *comments*, and **visuals** into one clean, professional notebook.
